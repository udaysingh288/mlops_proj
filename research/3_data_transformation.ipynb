# %%
import os
import pandas as pd

# %%
# %pwd
# Out:
# '/Users/drdre/Desktop/ML/mlops_proj'

# %%
#os.chdir('..')

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.DataScienceProject.constants import *
from src.DataScienceProject.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(self,
            config_filepath=CONFIG_FILE_PATH,
            params_filepath=PARAMS_FILE_PATH,
            schema_filepath=SCHEMA_FILE_PATH):
        self.config=read_yaml(config_filepath)
        self.params=read_yaml(params_filepath)
        self.schema=read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self)->DataTransformationConfig:
        config =self.config.data_transformation
        create_directories([config.root_dir])
        data_transformation_config=DataTransformationConfig(
            root_dir =config.root_dir,
            data_path=config.data_path
        )
        return data_transformation_config

# %%
import os
from src.DataScienceProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self,config:DataTransformationConfig):
        self.config=config

    def train_test_splitting(self):
        data= pd.read_csv(self.config.data_path)
        train,test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir,"train.csv"),index=False)
        test.to_csv(os.path.join(self.config.root_dir,"test.csv"),index=False)

        logger.info("Data split completed into train and test")
        logger.info(f"Training data shape: {train.shape}")
        logger.info(f"Testing data shape:{test.shape}")

        print(train.shape)
        print(test.shape)

# %%
try:
    config=ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation  = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2026-01-09 03:24:57,133: INFO: common: yaml file: config/config.yaml loaded success]
# [2026-01-09 03:24:57,134: INFO: common: yaml file: params.yaml loaded success]
# [2026-01-09 03:24:57,136: INFO: common: yaml file: schema.yaml loaded success]
# [2026-01-09 03:24:57,137: INFO: common: create directory at:artifacts]
# [2026-01-09 03:24:57,138: INFO: common: create directory at:artifacts/data_transformation]
# [2026-01-09 03:24:57,183: INFO: 1669655407: Data split completed into train and test]
# [2026-01-09 03:24:57,184: INFO: 1669655407: Training data shape: (1199, 12)]
# [2026-01-09 03:24:57,184: INFO: 1669655407: Testing data shape:(400, 12)]
# (1199, 12)
# (400, 12)
